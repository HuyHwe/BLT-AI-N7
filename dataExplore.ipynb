# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns

from linearRegression import LinearRegression

# %%
duong_dan = 'car_detail_cleaned.csv'

# %%
df = pd.read_csv(duong_dan)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize =(15,3))
ax1.scatter(df['year_of_manufacture'],df['Price'])
ax1.set_title('Price - Year of Manufacture')
ax2.scatter(df['mileage'],df['Price'])
ax2.set_title('Price - Millage')
plt.show()

# %%
log_price = np.log(df['Price'])
df['log_price'] = log_price
df
# Out:
#                   origin condition           car_model   mileage  \
# 93              Imported  Used car                 SUV   78000.0
# 181    Domestic assembly  Used car               Sedan   59000.0
# 195             Imported  Used car               Sedan   85000.0
# 318    Domestic assembly  Used car           Crossover   62000.0
# 397    Domestic assembly  Used car                 SUV    8000.0
# ...                  ...       ...                 ...       ...
# 29046  Domestic assembly  Used car                 SUV   55000.0
# 29047           Imported  Used car               Sedan   28000.0
# 29048           Imported  Used car  Bán tải / Pickup  158000.0
# 29049  Domestic assembly  Used car                 SUV   30000.0
# 29050           Imported  Used car                 SUV   10500.0
#
#       exterior_color interior_color num_of_doors seating_capacity  \
# 93            Yellow          Black       5-door           7-seat
# 181           Yellow          Cream       4-door           5-seat
# 195            White          Cream       4-door           5-seat
# 318             Sand           gray       5-door           8-seat
# 397            Black          Cream       5-door           5-seat
# ...              ...            ...          ...              ...
# 29046         Silver          Black       5-door           7-seat
# 29047          Black          Cream       4-door           5-seat
# 29048         Yellow          Black       4-door           5-seat
# 29049          White          Cream       5-door           5-seat
# 29050          Green          Black       5-door           5-seat
#
#               engine transmission                 drive_type fuel_consumption  \
# 93     Petrol\t3.6 L    Automatic  AWD - 4-wheel drive (AWD)          L/100Km
# 181    Petrol\t1.5 L       Manual    FWD - Front-wheel drive          L/100Km
# 195    Petrol\t3.5 L    Automatic     RFD - Rear-wheel drive          L/100Km
# 318    Petrol\t2.0 L       Manual     RFD - Rear-wheel drive       7\tL/100Km
# 397    Petrol\t2.0 L    Automatic  AWD - 4-wheel drive (AWD)          L/100Km
# ...              ...          ...                        ...              ...
# 29046         Petrol    Automatic     RFD - Rear-wheel drive          L/100Km
# 29047  Petrol\t2.5 L    Automatic    FWD - Front-wheel drive          L/100Km
# 29048         Petrol    Automatic    FWD - Front-wheel drive          L/100Km
# 29049  Petrol\t2.0 L    Automatic     RFD - Rear-wheel drive          L/100Km
# 29050         Petrol    Automatic  AWD - 4-wheel drive (AWD)          L/100Km
#
#          grade  year_of_manufacture                               car_name  \
# 93          Q7               2009.0             Audi Q7 S-line 3.6 AT 2009
# 181       Vios               2016.0                  Toyota Vios 1.5E 2016
# 195    S class               2006.0        Mercedes Benz S class S350 2006
# 318     Innova               2016.0            Toyota Innova 2.0E 2016 car
# 397        GLC               2019.0      Mercedes Benz GLC 200 4Matic 2019
# ...        ...                  ...                                    ...
# 29046  X trail               2017.0             Nissan X trail AT 2017 car
# 29047       ES               2021.0                      Lexus ES 250 2021
# 29048   Ranger               2016.0  Ford Ranger Wildtrack 3.2 4x4 AT 2016
# 29049      GLC               2020.0             Mercedes Benz GLC 200 2020
# 29050       Q8               2021.0      Audi Q8 55 TFSI S-Line Quatt 2021
#
#         Price  log_price
# 93      580.0   6.363028
# 181     311.0   5.739793
# 195     535.0   6.282267
# 318     368.0   5.908083
# 397    1679.0   7.425954
# ...       ...        ...
# 29046   595.0   6.388561
# 29047  2388.0   7.778211
# 29048   595.0   6.388561
# 29049  1459.0   7.285507
# 29050  3979.0   8.288786
#
# [19006 rows x 17 columns]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize =(15,3))
ax1.scatter(df['year_of_manufacture'],df['log_price'])
ax1.set_title('log_price - Year of Manufacture')
ax2.scatter(df['mileage'],df['log_price'])
ax2.set_title('log_price - Millage')
plt.show()

# %%
df_dummies = pd.get_dummies(df, drop_first=True)
df_dummies
df_dummies.to_csv("dummies.csv", index=False)

# %%
df
# Out:
#                   origin condition           car_model   mileage  \
# 93              Imported  Used car                 SUV   78000.0
# 181    Domestic assembly  Used car               Sedan   59000.0
# 195             Imported  Used car               Sedan   85000.0
# 318    Domestic assembly  Used car           Crossover   62000.0
# 397    Domestic assembly  Used car                 SUV    8000.0
# ...                  ...       ...                 ...       ...
# 29046  Domestic assembly  Used car                 SUV   55000.0
# 29047           Imported  Used car               Sedan   28000.0
# 29048           Imported  Used car  Bán tải / Pickup  158000.0
# 29049  Domestic assembly  Used car                 SUV   30000.0
# 29050           Imported  Used car                 SUV   10500.0
#
#       exterior_color interior_color num_of_doors seating_capacity  \
# 93            Yellow          Black       5-door           7-seat
# 181           Yellow          Cream       4-door           5-seat
# 195            White          Cream       4-door           5-seat
# 318             Sand           gray       5-door           8-seat
# 397            Black          Cream       5-door           5-seat
# ...              ...            ...          ...              ...
# 29046         Silver          Black       5-door           7-seat
# 29047          Black          Cream       4-door           5-seat
# 29048         Yellow          Black       4-door           5-seat
# 29049          White          Cream       5-door           5-seat
# 29050          Green          Black       5-door           5-seat
#
#               engine transmission                 drive_type fuel_consumption  \
# 93     Petrol\t3.6 L    Automatic  AWD - 4-wheel drive (AWD)          L/100Km
# 181    Petrol\t1.5 L       Manual    FWD - Front-wheel drive          L/100Km
# 195    Petrol\t3.5 L    Automatic     RFD - Rear-wheel drive          L/100Km
# 318    Petrol\t2.0 L       Manual     RFD - Rear-wheel drive       7\tL/100Km
# 397    Petrol\t2.0 L    Automatic  AWD - 4-wheel drive (AWD)          L/100Km
# ...              ...          ...                        ...              ...
# 29046         Petrol    Automatic     RFD - Rear-wheel drive          L/100Km
# 29047  Petrol\t2.5 L    Automatic    FWD - Front-wheel drive          L/100Km
# 29048         Petrol    Automatic    FWD - Front-wheel drive          L/100Km
# 29049  Petrol\t2.0 L    Automatic     RFD - Rear-wheel drive          L/100Km
# 29050         Petrol    Automatic  AWD - 4-wheel drive (AWD)          L/100Km
#
#          grade  year_of_manufacture                               car_name  \
# 93          Q7               2009.0             Audi Q7 S-line 3.6 AT 2009
# 181       Vios               2016.0                  Toyota Vios 1.5E 2016
# 195    S class               2006.0        Mercedes Benz S class S350 2006
# 318     Innova               2016.0            Toyota Innova 2.0E 2016 car
# 397        GLC               2019.0      Mercedes Benz GLC 200 4Matic 2019
# ...        ...                  ...                                    ...
# 29046  X trail               2017.0             Nissan X trail AT 2017 car
# 29047       ES               2021.0                      Lexus ES 250 2021
# 29048   Ranger               2016.0  Ford Ranger Wildtrack 3.2 4x4 AT 2016
# 29049      GLC               2020.0             Mercedes Benz GLC 200 2020
# 29050       Q8               2021.0      Audi Q8 55 TFSI S-Line Quatt 2021
#
#         Price  log_price
# 93      580.0   6.363028
# 181     311.0   5.739793
# 195     535.0   6.282267
# 318     368.0   5.908083
# 397    1679.0   7.425954
# ...       ...        ...
# 29046   595.0   6.388561
# 29047  2388.0   7.778211
# 29048   595.0   6.388561
# 29049  1459.0   7.285507
# 29050  3979.0   8.288786
#
# [19006 rows x 17 columns]

# %%
df_to_encode = df

# %%
from sklearn.preprocessing import TargetEncoder
target_encoder = TargetEncoder()
categorical_cols = [
    'origin', 'condition', 'car_model', 'exterior_color', 'interior_color',
    'num_of_doors', 'seating_capacity', 'engine', 'transmission',
    'drive_type', 'fuel_consumption', 'grade', 'car_name'
]
df_to_encode[categorical_cols] = target_encoder.fit_transform(df_to_encode[categorical_cols], df_to_encode['log_price'])

# Rename the encoded columns to have a suffix like '_target_encoded' for clarity
encoded_col_names = {col: col + '_target_encoded' for col in categorical_cols if col in df_to_encode.columns}
df_to_encode = df_to_encode.rename(columns=encoded_col_names)

# %%
df_to_encode
# Out:
#        origin_target_encoded  condition_target_encoded  \
# 93                  6.672420                  6.445401
# 181                 6.293303                  6.445095
# 195                 6.677725                  6.445734
# 318                 6.293793                  6.449818
# 397                 6.292914                  6.445401
# ...                      ...                       ...
# 29046               6.293793                  6.449818
# 29047               6.680059                  6.449818
# 29048               6.669924                  6.445095
# 29049               6.299397                  6.454239
# 29050               6.677725                  6.445734
#
#        car_model_target_encoded   mileage  exterior_color_target_encoded  \
# 93                     6.778546   78000.0                       6.286657
# 181                    6.401939   59000.0                       6.306689
# 195                    6.410401   85000.0                       6.515658
# 318                    6.265399   62000.0                       6.106219
# 397                    6.778546    8000.0                       6.698456
# ...                         ...       ...                            ...
# 29046                  6.769777   55000.0                       5.941232
# 29047                  6.416063   28000.0                       6.692398
# 29048                  6.347937  158000.0                       6.306689
# 29049                  6.782406   30000.0                       6.529174
# 29050                  6.765429   10500.0                       6.414839
#
#        interior_color_target_encoded  num_of_doors_target_encoded  \
# 93                          6.439572                     6.489693
# 181                         6.484137                     6.390187
# 195                         6.481545                     6.396194
# 318                         5.926678                     6.496372
# 397                         6.484038                     6.489693
# ...                              ...                          ...
# 29046                       6.440832                     6.496372
# 29047                       6.481757                     6.396697
# 29048                       6.436931                     6.390187
# 29049                       6.487575                     6.505028
# 29050                       6.436383                     6.487199
#
#        seating_capacity_target_encoded  engine_target_encoded  \
# 93                            6.698079               7.215131
# 181                           6.395552               6.220531
# 195                           6.401545               7.380742
# 318                           6.332730               6.678434
# 397                           6.398233               6.686112
# ...                                ...                    ...
# 29046                         6.693017               6.373481
# 29047                         6.400537               6.551112
# 29048                         6.395552               6.363452
# 29049                         6.407576               6.688183
# 29050                         6.401545               6.361991
#
#        transmission_target_encoded  drive_type_target_encoded  \
# 93                        6.564668                   7.346810
# 181                       5.706379                   6.142212
# 195                       6.565526                   6.612789
# 318                       5.710444                   6.621476
# 397                       6.564668                   7.346810
# ...                            ...                        ...
# 29046                     6.570478                   6.621476
# 29047                     6.570478                   6.143276
# 29048                     6.564111                   6.142212
# 29049                     6.571787                   6.630460
# 29050                     6.565526                   7.346094
#
#        fuel_consumption_target_encoded  grade_target_encoded  \
# 93                            6.596934              6.855423
# 181                           6.602273              5.998756
# 195                           6.600537              7.772139
# 318                           6.240592              6.084109
# 397                           6.596934              7.115339
# ...                                ...                   ...
# 29046                         6.605573              6.463195
# 29047                         6.605573              7.316749
# 29048                         6.602273              6.359127
# 29049                         6.610032              7.130708
# 29050                         6.600537              7.967067
#
#        year_of_manufacture  car_name_target_encoded   Price  log_price
# 93                  2009.0                 6.445753   580.0   6.363028
# 181                 2016.0                 5.792006   311.0   5.739793
# 195                 2006.0                 6.446109   535.0   6.282267
# 318                 2016.0                 6.032724   368.0   5.908083
# 397                 2019.0                 7.244228  1679.0   7.425954
# ...                    ...                      ...     ...        ...
# 29046               2017.0                 6.450040   595.0   6.388561
# 29047               2021.0                 7.778365  2388.0   7.778211
# 29048               2016.0                 6.445426   595.0   6.388561
# 29049               2020.0                 7.236044  1459.0   7.285507
# 29050               2021.0                 6.446109  3979.0   8.288786
#
# [19006 rows x 17 columns]

# %%
df_to_encode.sample(10).T
# Out:
#                                          7210           4420          12266  \
# origin_target_encoded                 6.288949       6.669924      6.680600
# condition_target_encoded              6.445734       6.445095      6.454239
# car_model_target_encoded              6.410401       6.774171      6.413122
# mileage                          125000.000000  100000.000000  19000.000000
# exterior_color_target_encoded         6.687462       6.383808      6.686643
# interior_color_target_encoded         6.481545       6.484137      6.487575
# num_of_doors_target_encoded           6.396194       6.493478      6.398821
# seating_capacity_target_encoded       6.401545       6.395552      6.407576
# engine_target_encoded                 6.107543       7.376338      7.729230
# transmission_target_encoded           6.565526       6.564111      6.571787
# drive_type_target_encoded             6.139737       7.332932      7.350151
# fuel_consumption_target_encoded       6.085550       6.392686      6.610032
# grade_target_encoded                  6.107342       7.630493      8.275199
# year_of_manufacture                2013.000000    2010.000000   2019.000000
# car_name_target_encoded               6.090324       5.616648      8.004921
# Price                               450.000000    1100.000000    850.000000
# log_price                             6.109248       7.003065      6.745236
#
#                                         8179          20998          20097  \
# origin_target_encoded                6.680059      6.293793       6.293793
# condition_target_encoded             6.449818      6.449818       6.449818
# car_model_target_encoded             6.416063      6.265399       6.416063
# mileage                          24000.000000  15000.000000  150000.000000
# exterior_color_target_encoded        6.518663      6.383087       6.692398
# interior_color_target_encoded        6.440832      6.440832       5.926678
# num_of_doors_target_encoded          6.396697      6.496372       6.496372
# seating_capacity_target_encoded      6.400537      6.400537       6.400537
# engine_target_encoded                5.959689      6.678434       6.103742
# transmission_target_encoded          6.570478      6.570478       6.570478
# drive_type_target_encoded            6.143276      6.143276       6.143276
# fuel_consumption_target_encoded      5.870424      6.605573       6.376834
# grade_target_encoded                 5.881262      6.365971       4.795303
# year_of_manufacture               2021.000000   2021.000000    2004.000000
# car_name_target_encoded              6.052089      6.426324       4.924194
# Price                              420.000000    625.000000     139.000000
# log_price                            6.040255      6.437752       4.934474
#
#                                         926           19228         13743  \
# origin_target_encoded                6.669924      6.293303      6.299397
# condition_target_encoded             6.445095      6.445095      6.454239
# car_model_target_encoded             6.774171      6.774171      6.274277
# mileage                          80000.000000  43000.000000  60940.000000
# exterior_color_target_encoded        6.366326      6.516916      6.686643
# interior_color_target_encoded        6.815350      6.996471      6.445559
# num_of_doors_target_encoded          6.493478      6.493478      6.505028
# seating_capacity_target_encoded      6.395552      6.395552      6.341845
# engine_target_encoded                6.687069      6.687069      6.688183
# transmission_target_encoded          6.564111      6.564111      6.571787
# drive_type_target_encoded            7.332932      7.332932      6.630460
# fuel_consumption_target_encoded      6.602273      6.392686      6.605687
# grade_target_encoded                 6.655054      7.140421      6.067148
# year_of_manufacture               2012.000000   2019.000000   2018.000000
# car_name_target_encoded              6.640716      7.159174      6.469726
# Price                              945.000000   1399.000000    700.000000
# log_price                            6.851185      7.243513      6.551080
#
#                                         17583
# origin_target_encoded                6.299397
# condition_target_encoded             6.454239
# car_model_target_encoded             6.413122
# mileage                          56000.000000
# exterior_color_target_encoded        6.686643
# interior_color_target_encoded        5.916132
# num_of_doors_target_encoded          6.398821
# seating_capacity_target_encoded      6.407576
# engine_target_encoded                6.216961
# transmission_target_encoded          6.571787
# drive_type_target_encoded            6.148322
# fuel_consumption_target_encoded      6.610032
# grade_target_encoded                 5.998716
# year_of_manufacture               2020.000000
# car_name_target_encoded              6.236811
# Price                              520.000000
# log_price                            6.253829

# %%
df_to_encode.columns
# Out:
# Index(['origin_target_encoded', 'condition_target_encoded',
#        'car_model_target_encoded', 'mileage', 'exterior_color_target_encoded',
#        'interior_color_target_encoded', 'num_of_doors_target_encoded',
#        'seating_capacity_target_encoded', 'engine_target_encoded',
#        'transmission_target_encoded', 'drive_type_target_encoded',
#        'fuel_consumption_target_encoded', 'grade_target_encoded',
#        'year_of_manufacture', 'car_name_target_encoded', 'Price', 'log_price'],
#       dtype='object')

# %%
df_to_encode.to_csv('dataset.csv', index=False)

# %%
df_to_encode.isnull().sum()
# Out:
# origin_target_encoded              0
# condition_target_encoded           0
# car_model_target_encoded           0
# mileage                            0
# exterior_color_target_encoded      0
# interior_color_target_encoded      0
# num_of_doors_target_encoded        0
# seating_capacity_target_encoded    0
# engine_target_encoded              0
# transmission_target_encoded        0
# drive_type_target_encoded          0
# fuel_consumption_target_encoded    0
# grade_target_encoded               0
# year_of_manufacture                0
# car_name_target_encoded            0
# Price                              0
# log_price                          0
# dtype: int64
